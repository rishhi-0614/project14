# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
cars=pd.read_csv(r"C:\Users\Khush\Downloads\Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
sns.displot(x=cars['HP'],color='Grey')
plt.show()

# %%
sns.histplot(x=cars['VOL'])
# Out:
# <Axes: xlabel='VOL', ylabel='Count'>

# %%
sns.histplot(x=cars['MPG'])
# Out:
# <Axes: xlabel='MPG', ylabel='Count'>

# %%
sns.boxplot(x=cars.HP)
plt.show()

# %%
sns.scatterplot(x=cars['WT'],y=cars['MPG'])
# Out:
# <Axes: xlabel='WT', ylabel='MPG'>

# %%
sns.scatterplot(x=cars['VOL'], y=cars['MPG'])

plt.show()

# %%
cars = pd.DataFrame({'VOL': [100, 150, 200], 'MPG': [25, 22, 18]})  # Ensure 'VOL' and 'MPG' exist
sns.barplot(x=cars['VOL'].astype(str), y=cars['MPG'])  # Convert VOL to string if numeric
plt.show()

# %%
cars = pd.DataFrame({'HP': [100, 150, 200, 700, 350, 800, 280], 'WT': [120, 130, 140, 340, 560, 800, 900]})  # Ensure 'HP' and 'SP' exist

sns.scatterplot(x=cars['HP'], y=cars['WT'])
plt.show()

# %%
cars = pd.DataFrame({'HP': [100, 150, 200, 300, 700, 250, 350], 'SP': [120, 130, 500, 180, 100, 250, 140]})  # Ensure 'HP' and 'SP' exist
sns.scatterplot(x=cars['HP'], y=cars['SP'])
plt.show()
